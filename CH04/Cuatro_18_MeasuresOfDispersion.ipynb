# %%
values = [1,3,4,2,6,5,3,4,5,2]

# %%
sum(values)
# Out:
# 35

# %%
average = sum(values) / len(values)

# %%
average
# Out:
# 3.5

# %%
listValues = []
for value in values:
    value -= average
    listValues.append(value)

# %%
listValues
# Out:
# [-2.5, -0.5, 0.5, -1.5, 2.5, 1.5, -0.5, 0.5, 1.5, -1.5]

# %%
listValuesSquare = []
for value in listValues:
    value **= 2
    listValuesSquare.append(value)

# %%
listValuesSquare
# Out:
# [6.25, 0.25, 0.25, 2.25, 6.25, 2.25, 0.25, 0.25, 2.25, 2.25]

# %%
newAverage = sum(listValuesSquare) / len(listValuesSquare)

# %%
newAverage          #Population variance
# Out:
# 2.25

# %%
deviation = newAverage ** (1/2)
deviation
# Out:
# 1.5

# %%
import statistics as stats

# %%
stats.pvariance(values)
# Out:
# 2.25

# %%
stats.pstdev(values)
# Out:
# 1.5
