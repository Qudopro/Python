# %%
def rectangle_area(length=2, width=3):
    """Return the area of a rectangle."""
    return length * width

# %%
rectangle_area()
# Out:
# 6

# %%
rectangle_area(10)
# Out:
# 30

# %%
rectangle_area(20, 30)
# Out:
# 600
