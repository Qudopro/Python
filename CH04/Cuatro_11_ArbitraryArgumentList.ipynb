# %%
def average(*args):
    return sum(args) / len(args)

# %%
average(3,5)
# Out:
# 4.0

# %%
average(1,2,3,4)
# Out:
# 2.5

# %%
grades = [43,32,32,43,54,67]
average(*grades)
# Out:
# 45.166666666666664
