# %%
x = 7               #Global variable

# %%
def access_global():
    print("x printed from access global", x)

# %%
access_global()
# Out:
# x printed from access global 7

# %%
def try_to_modify_global():
    x = 32.3                    #Local variable
    print("x printed from try to modify global", x)

# %%
try_to_modify_global()
access_global()
# Out:
# x printed from try to modify global 32.3
# x printed from access global 7

# %%
x
# Out:
# 7

# %%
def modify_global():
    global x                        #Global variable
    x = "Hello"
    print("x printed from modify global", x)

# %%
modify_global()
try_to_modify_global()
access_global()
# Out:
# x printed from modify global Hello
# x printed from try to modify global 32.3
# x printed from access global Hello

# %%
x
# Out:
# 'Hello'

# %%
sum = 10 + 5
sum
# Out:
# 15

# %%
sum([10, 5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sum([10, 5])
#
# TypeError: 'int' object is not callable
