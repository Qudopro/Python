# %%
x = 7

# %%
id(x)
# Out:
# 140719884772664

# %%
def cube(number):
    print("id(number):", id(number))
    print("number is x:", number is x)          #is Operator returns True if its two operands have the same identity
    return number**3

# %%
cube(x)
# Out:
# id(number): 140719884772664
# number is x: True
# 343

# %%
x
# Out:
# 7

# %%
def square(number):
    print("id(number) before modifying number:", id(number))
    number **= 2
    print("id(number) after modifying number:", id(number))
    return number

# %%
square(x)
# Out:
# id(number) before modifying number: 140719884772664
# id(number) after modifying number: 140719884774008
# 49

# %%
print(x)
id(x)
# Out:
# 7
# 140719884772664
