# %%
import math

# %%
math.sqrt(900)
# Out:
# 30.0

# %%
math.fabs(-10)
# Out:
# 10.0

# %%
math.ceil(9.2)
# Out:
# 10

# %%
math.floor(9.2)
# Out:
# 9

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.cos(90)
# Out:
# -0.4480736161291701

# %%
math.tan(90)
# Out:
# -1.995200412208242

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.log(2.71)
# Out:
# 0.9969486348916096

# %%
math.log10(10)
# Out:
# 1.0

# %%
math.pow(2,10)
# Out:
# 1024.0

# %%
math.fmod(9.8, 4.0)
# Out:
# 1.8000000000000007

# %%
math.comb?
