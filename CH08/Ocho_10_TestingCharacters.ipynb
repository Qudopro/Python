# %%
'-27'.isdigit()
# Out:
# False

# %%
'27'.isdigit()
# Out:
# True

# %%
'A98'.isalnum()
# Out:
# True

# %%
'123 Main Street'.isalnum()
# Out:
# False

# %%
'abc'.isalpha()
# Out:
# True

# %%
'abc'.islower()
# Out:
# True

# %%
' '.isspace()
# Out:
# True

# %%
'Hola Mundo'.istitle()
# Out:
# True

# %%
'HI'.isupper()
# Out:
# True
