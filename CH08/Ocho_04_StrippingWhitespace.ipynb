# %%
sentence = '\t \n This is a test string \t \n'
print(sentence)
# Out:
#
#  This is a test string

# %%
sentence.strip()
# Out:
# 'This is a test string'

# %%
sentence.lstrip()
# Out:
# 'This is a test string \t \n'

# %%
sentence.rstrip()
# Out:
# '\t \n This is a test string'
