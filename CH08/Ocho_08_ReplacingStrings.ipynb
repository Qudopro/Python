# %%
values = ('1\t2\t3\t4\t5\t6\t7\t8\t9')
# Out:
# '1,2,3,4,5,6,7,8,9'

# %%
values.replace('\t', ',')
# Out:
# '1,2,3,4,5,6,7,8,9'

# %%
values.replace('\t', ',', 2)
# Out:
# '1,2,3\t4\t5\t6\t7\t8\t9'
