# %%
f'{17.489:.2f}'
# Out:
# '17.49'

# %%
f'{10:d}'
# Out:
# '10'

# %%
f'{65:c} {97:c}'
# Out:
# 'A a'

# %%
f'{"Hello":s} {7}'
# Out:
# 'Hello 7'

# %%
from decimal import Decimal
f'{Decimal("10000000000000000000000.0"):.3E}'
# Out:
# '1.000E+22'

# %%
f'[{27:10d}]'
# Out:
# '[        27]'

# %%
f'[{3.5:10f}]'
# Out:
# '[  3.500000]'

# %%
f'[{"hello":15}]'
# Out:
# '[hello          ]'

# %%
f'[{27:<15d}]'
# Out:
# '[27             ]'

# %%
f'[{3.5:<15f}]'
# Out:
# '[3.500000       ]'

# %%
f'[{"hello":>15}]'
# Out:
# '[          hello]'

# %%
f'[{27:^7d}]'
# Out:
# '[  27   ]'

# %%
f'[{3.5:^7.1f}]'
# Out:
# '[  3.5  ]'

# %%
f'[{"hello":^7}]'
# Out:
# '[ hello ]'

# %%
f'[{27:+10d}]'                  #Forzar un signo positivo
# Out:
# '[       +27]'

# %%
f'[{27:+010d}]'                 #Llenar con 0's los espacios en blanco
# Out:
# '[+000000027]'

# %%
print(f'{27:d}\n{27: d}\n{-27:d}')
# Out:
# 27
#  27
# -27

# %%
f'{12345679:,d}'
# Out:
# '12,345,679'

# %%
'{:2f}'.format(17.489)
# Out:
# '17.489000'

# %%
'{} {}'.format('Diego','Cabrera')
# Out:
# 'Diego Cabrera'

# %%
'{0} {0} {1}'.format('Happy', 'Birthday')
# Out:
# 'Happy Happy Birthday'

# %%
'{first} {last}'.format(first='Diego', last='Cabrera')
# Out:
# 'Diego Cabrera'
