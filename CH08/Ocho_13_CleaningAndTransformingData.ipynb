# %%
import pandas as pd

# %%
zips = pd.Series({'Boston':'02215', 'Miami':'3310'})

# %%
zips
# Out:
# Boston    02215
# Miami      3310
# dtype: str

# %%
print(zips.str.match(r'\d{5}'))
# Out:
# Boston     True
# Miami     False
# dtype: bool

# %%
cities = pd.Series(['Boston,  MA  02215', 'Miami,  FL  33101'])
cities
# Out:
# 0    Boston,  MA  02215
# 1     Miami,  FL  33101
# dtype: str

# %%
cities.str.contains(r' [A-Z]{2}  ')
# Out:
# 0    True
# 1    True
# dtype: bool

# %%
cities.str.match(r'  [A-Z]{2}  ')
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
contacts = [['Mike Green', 'demo1@deitel.com', '5555551234'], ['Diego Cabrera', 'diego@deitel.com', '5554443333']]
print(contacts)
# Out:
# [['Mike Green', 'demo1@deitel.com', '5555551234'], ['Diego Cabrera', 'diego@deitel.com', '5554443333']]

# %%
contactsdf = pd.DataFrame(contacts, columns=['Name', 'Email', 'Phone'])
contactsdf
# Out:
#             Name             Email       Phone
# 0     Mike Green  demo1@deitel.com  5555551234
# 1  Diego Cabrera  diego@deitel.com  5554443333

# %%
import re

# %%
def get_formatted_phone(value):
    result = re.fullmatch(r'(\d{3})(\d{3})(\d{4})', value)
    return '-'.join(result.groups()) if result else value

# %%
formatted_phone = contactsdf['Phone'].map(get_formatted_phone)

# %%
contactsdf['Phone'] = formatted_phone

# %%
print(contactsdf)
# Out:
#             Name             Email         Phone
# 0     Mike Green  demo1@deitel.com  555-555-1234
# 1  Diego Cabrera  diego@deitel.com  555-444-3333
