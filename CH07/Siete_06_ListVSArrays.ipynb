# %%
import random

# %%
# %timeit rolls_list = [random.randrange(1,7) for i in range(0,6_000_000)]
# Out:
# 632 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %timeit rolls_array = np.random.randint(1,7,6_000_000)
# Out:
# 24.1 ms ± 147 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit -n3 -r2 rolls_array = np.random.randint(1,7,6_000_000)
# Out:
# 25.6 ms ± 1.05 ms per loop (mean ± std. dev. of 2 runs, 3 loops each)
