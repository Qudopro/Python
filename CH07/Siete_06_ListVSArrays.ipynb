# %%
import random

# %%
# %timeit rolls_list = [random.randrange(1,7) for i in range(0,6_000_000)]
# Out:
# 1.11 s ± 22.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %timeit rolls_array = np.random.randint(1,7,6_000_000)
# Out:
# 38.4 ms ± 749 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit rolls_array = np.random.randint(1,7,60_000_000)
# Out:
# 378 ms ± 2.94 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit rolls_array = np.random.randint(1,7,600_000_000)
# Out:
# 4.07 s ± 82 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit -n3 -r2 rolls_array = np.random.randint(1,7,6_000_000)
# Out:
# 36.6 ms ± 233 μs per loop (mean ± std. dev. of 2 runs, 3 loops each)
