# %%
import numpy as np

# %%
numbers = np.arange(1,6)
numbers
# Out:
# array([1, 2, 3, 4, 5])

# %%
numbers*2
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
numbers ** 3
# Out:
# array([  1,   8,  27,  64, 125])

# %%
numbers             #Numbers is unchanged by the arithmetic operators
# Out:
# array([1, 2, 3, 4, 5])

# %%
numbers += 10           #Augmented assignments modify every element in the left operand

# %%
numbers
# Out:
# array([11, 12, 13, 14, 15])

# %%
numbers2 = np.linspace(1.1,5.5,5)

# %%
numbers*numbers2                #Both arrays have the same shape
# Out:
# array([12.1, 26.4, 42.9, 61.6, 82.5])

# %%
numbers
# Out:
# array([1, 2, 3, 4, 5])

# %%
(numbers >= 13)
# Out:
# array([False, False, False, False, False])

# %%
numbers2 < numbers
# Out:
# array([False, False, False, False, False])

# %%
numbers == numbers2
# Out:
# array([False, False, False, False, False])

# %%
numbers == numbers
# Out:
# array([ True,  True,  True,  True,  True])
