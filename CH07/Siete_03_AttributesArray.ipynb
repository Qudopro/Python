# %%
import numpy as np

# %%
integers = np.array([[1,2,3,],[4,5,6]])
integers
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
floats = np.array([0.1,0.2,0.3])
floats
# Out:
# array([0.1, 0.2, 0.3])

# %%
integers.dtype
# Out:
# dtype('int64')

# %%
floats.dtype
# Out:
# dtype('float64')

# %%
integers.ndim
# Out:
# 2

# %%
floats.ndim
# Out:
# 1

# %%
integers.shape
# Out:
# (2, 3)

# %%
floats.shape
# Out:
# (3,)

# %%
integers.size
# Out:
# 6

# %%
floats.size
# Out:
# 3

# %%
integers.itemsize
# Out:
# 8

# %%
floats.itemsize
# Out:
# 8

# %%
for row in integers:
    for column in row:
        print(column, end=" ")
    print()
# Out:
# 1 2 3
# 4 5 6

# %%
for i in integers.flat:
    print(i, end=" ")
# Out:
# 1 2 3 4 5 6
