# %%
import pandas as pd

# %%
grades_dict = {'Wally': [100,98,76], 'Eva': [84,75,99]}

# %%
grades = pd.DataFrame(grades_dict)
grades
# Out:
#    Wally  Eva
# 0    100   84
# 1     98   75
# 2     76   99

# %%
grades.index = ['Test1','Test2','Test3']

# %%
grades
# Out:
#        Wally  Eva
# Test1    100   84
# Test2     98   75
# Test3     76   99

# %%
grades['Eva']
# Out:
# Test1    84
# Test2    75
# Test3    99
# Name: Eva, dtype: int64

# %%
grades.Wally
# Out:
# Test1    100
# Test2     98
# Test3     76
# Name: Wally, dtype: int64

# %%
grades.loc['Test1']
# Out:
# Wally    100
# Eva       84
# Name: Test1, dtype: int64

# %%
grades.iloc[0]
# Out:
# Wally    100
# Eva       84
# Name: Test1, dtype: int64

# %%
grades.loc['Test1':'Test3']
# Out:
#        Wally  Eva
# Test1    100   84
# Test2     98   75
# Test3     76   99

# %%
grades.iloc[0:2]
# Out:
#        Wally  Eva
# Test1    100   84
# Test2     98   75

# %%
grades.loc[['Test1','Test3']]
# Out:
#        Wally  Eva
# Test1    100   84
# Test3     76   99

# %%
grades.iloc[[0,2]]
# Out:
#        Wally  Eva
# Test1    100   84
# Test3     76   99

# %%
grades.loc['Test1':'Test3', ['Eva', 'Wally']]
# Out:
#        Eva  Wally
# Test1   84    100
# Test2   75     98
# Test3   99     76

# %%
grades.iloc[[0,2], 0:3]
# Out:
#        Wally  Eva
# Test1    100   84
# Test3     76   99

# %%
grades[grades>=90]
# Out:
#        Wally   Eva
# Test1  100.0   NaN
# Test2   98.0   NaN
# Test3    NaN  99.0

# %%
grades[(grades>=80)&(grades<90)]
# Out:
#        Wally  Eva
# Test1    NaN  NaN
# Test2    NaN  NaN
# Test3    NaN  NaN

# %%
grades.at['Test1','Eva']
# Out:
# np.int64(84)

# %%
grades.iat[0,0]
# Out:
# np.int64(100)

# %%
grades.at['Test1','Eva'] = 100

# %%
grades.describe()
# Out:
#             Wally         Eva
# count    3.000000    3.000000
# mean    91.333333   91.333333
# std     13.316656   14.153916
# min     76.000000   75.000000
# 25%     87.000000   87.000000
# 50%     98.000000   99.000000
# 75%     99.000000   99.500000
# max    100.000000  100.000000

# %%
pd.set_option('precision', 2)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pd.set_option('precision', 2)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/_config/config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/_config/config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/_config/config.py:134, in _get_single_key(pat, silent)
#     132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
# --> 134     raise OptionError("Pattern matched multiple keys")
#     135 key = keys[0]
#     137 if not silent:
#
# OptionError: 'Pattern matched multiple keys'

# %%
grades.mean()
# Out:
# Wally    91.333333
# Eva      91.333333
# dtype: float64

# %%
grades.T
# Out:
#        Test1  Test2  Test3
# Wally    100     98     76
# Eva      100     75     99

# %%
grades.T.describe()
# Out:
#        Test1      Test2      Test3
# count    2.0   2.000000   2.000000
# mean   100.0  86.500000  87.500000
# std      0.0  16.263456  16.263456
# min    100.0  75.000000  76.000000
# 25%    100.0  80.750000  81.750000
# 50%    100.0  86.500000  87.500000
# 75%    100.0  92.250000  93.250000
# max    100.0  98.000000  99.000000

# %%
grades.sort_index(ascending=False)
# Out:
#        Wally  Eva
# Test3     76   99
# Test2     98   75
# Test1    100  100

# %%
grades.sort_index(axis=1)
# Out:
#        Eva  Wally
# Test1  100    100
# Test2   75     98
# Test3   99     76

# %%
grades.sort_values(by='Test1', axis=1, ascending=False)
# Out:
#        Wally  Eva
# Test1    100  100
# Test2     98   75
# Test3     76   99

# %%
grades.T.sort_values(by='Test1', ascending=False)
# Out:
#        Test1  Test2  Test3
# Wally    100     98     76
# Eva      100     75     99

# %%
grades.loc['Test1'].sort_values(ascending=False)
# Out:
# Wally    100
# Eva      100
# Name: Test1, dtype: int64
