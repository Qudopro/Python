# %%
import numpy as np

# %%
grades = np.array([[87,98,56],[78,86,85]])
grades
# Out:
# array([[87, 98, 56],
#        [78, 86, 85]])

# %%
grades.reshape(1,6)                 #Returns a view
# Out:
# array([[87, 98, 56, 78, 86, 85]])

# %%
grades.resize(1,6)                  #Returns a view and it modifies the original array's shape
grades
# Out:
# array([[87, 98, 56, 78, 86, 85]])

# %%
flattened = grades.flatten()        #Deep copies the original array's data

# %%
flattened
# Out:
# array([87, 98, 56, 78, 86, 85])

# %%
grades
# Out:
# array([[87, 98, 56],
#        [78, 86, 85]])

# %%
raveled = grades.ravel()            #It produces a view of the original array

# %%
raveled
# Out:
# array([87, 98, 56, 78, 86, 85])

# %%
grades.T                #Returns a transposed view of the array
# Out:
# array([[87, 78],
#        [98, 86],
#        [56, 85]])

# %%
grades
# Out:
# array([[87, 98, 56],
#        [78, 86, 85]])

# %%
grades2 = np.array([[87,98,56],[78,86,85]])
grades2
# Out:
# array([[87, 98, 56],
#        [78, 86, 85]])

# %%
np.hstack((grades,grades2))
# Out:
# array([[87, 98, 56, 87, 98, 56],
#        [78, 86, 85, 78, 86, 85]])

# %%
np.vstack((grades,grades2))
# Out:
# array([[87, 98, 56],
#        [78, 86, 85],
#        [87, 98, 56],
#        [78, 86, 85]])
