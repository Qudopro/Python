# %%
import numpy as np

# %%
grades = np.array([[87,98,56],[78,86,85]])
grades
# Out:
# array([[87, 98, 56],
#        [78, 86, 85]])

# %%
grades.reshape(1,6)
# Out:
# array([[87, 98, 56, 78, 86, 85]])

# %%
grades.resize(1,6)
grades
# Out:
# array([[87, 98, 56, 78, 86, 85]])

# %%
flattened = grades.flatten()

# %%
flattened
# Out:
# array([87, 98, 56, 78, 86, 85])

# %%
raveled = grades.ravel()

# %%
raveled
# Out:
# array([87, 98, 56, 78, 86, 85])

# %%
grades.T
# Out:
# array([[87],
#        [98],
#        [56],
#        [78],
#        [86],
#        [85]])

# %%
grades2 = np.array([[87,98,56],[78,86,85]])

# %%
np.hstack((grades,grades2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.hstack((grades,grades2))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/_core/shape_base.py:367, in hstack(tup, dtype, casting)
#     365     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     366 else:
# --> 367     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 1 and the array at index 1 has size 2

# %%
np.vstack((grades,grades2))
# Out:
# array([[87, 98, 56],
#        [78, 86, 85],
#        [87, 98, 56],
#        [78, 86, 85]])
