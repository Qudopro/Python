# %%
import numpy as np

# %%
grades = np.array([[87,96,70],[77,78,89]])
grades
# Out:
# array([[87, 96, 70],
#        [77, 78, 89]])

# %%
grades.dtype
# Out:
# dtype('int64')

# %%
grades.sum()
# Out:
# np.int64(497)

# %%
grades.min()
# Out:
# np.int64(70)

# %%
grades.max()
# Out:
# np.int64(96)

# %%
grades.mean()
# Out:
# np.float64(82.83333333333333)

# %%
grades.std()
# Out:
# np.float64(8.668269082630562)

# %%
grades.var()
# Out:
# np.float64(75.13888888888889)

# %%
grades.mean(axis=0)
# Out:
# array([82. , 87. , 79.5])

# %%
grades.mean(axis=1)
# Out:
# array([84.33333333, 81.33333333])
