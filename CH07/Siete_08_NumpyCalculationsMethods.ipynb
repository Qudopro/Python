# %%
import numpy as np

# %%
grades = np.array([[87,96,70],[77,78,89], [95,77,90],[100,81,87]])
grades
# Out:
# array([[ 87,  96,  70],
#        [ 77,  78,  89],
#        [ 95,  77,  90],
#        [100,  81,  87]])

# %%
grades.dtype
# Out:
# dtype('int64')

# %%
grades.sum()
# Out:
# np.int64(1027)

# %%
grades.min()
# Out:
# np.int64(70)

# %%
grades.max()
# Out:
# np.int64(100)

# %%
grades.mean()
# Out:
# np.float64(85.58333333333333)

# %%
grades.std()
# Out:
# np.float64(8.703048635711257)

# %%
grades.var()
# Out:
# np.float64(75.74305555555556)

# %%
grades.mean(axis=0)             #Calculation on all the row values within each column
# Out:
# array([89.75, 83.  , 84.  ])

# %%
grades.mean(axis=1)             #Calculation on all the column values within each individual row
# Out:
# array([84.33333333, 81.33333333, 87.33333333, 89.33333333])
