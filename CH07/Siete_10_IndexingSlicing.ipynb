# %%
import numpy as np

# %%
grades = np.array([[87,96,70],[100,87,90],[94,74,75],[100,81,82]])
grades
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90],
#        [ 94,  74,  75],
#        [100,  81,  82]])

# %%
grades[0,1]                 #Select a element
# Out:
# np.int64(96)

# %%
grades[1]                   #Select a single row
# Out:
# array([100,  87,  90])

# %%
grades[0:2]                 #Select multiple sequential rows
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90]])

# %%
grades[[1,3]]               #Select multiple non-sequential rows
# Out:
# array([[100,  87,  90],
#        [100,  81,  82]])

# %%
grades[:,0]                 #Select a single column
# Out:
# array([ 87, 100,  94, 100])

# %%
grades[:,1:3]               #Select consecutive column
# Out:
# array([[96, 70],
#        [87, 90],
#        [74, 75],
#        [81, 82]])

# %%
grades[:,[0,2]]             #Select specific columns
# Out:
# array([[ 87,  70],
#        [100,  90],
#        [ 94,  75],
#        [100,  82]])
