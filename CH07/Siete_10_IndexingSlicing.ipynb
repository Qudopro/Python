# %%
import numpy as np

# %%
grades = np.array([[87,96,70],[100,87,90],[94,74,75],[100,81,82]])

# %%
grades[0,1]
# Out:
# np.int64(96)

# %%
grades[1]
# Out:
# array([100,  87,  90])

# %%
grades[0:2]
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90]])

# %%
grades[[1,3]]
# Out:
# array([[100,  87,  90],
#        [100,  81,  82]])

# %%
grades[:,0]
# Out:
# array([ 87, 100,  94, 100])

# %%
grades[:,1:3]
# Out:
# array([[96, 70],
#        [87, 90],
#        [74, 75],
#        [81, 82]])

# %%
grades[:,[0,2]]
# Out:
# array([[ 87,  70],
#        [100,  90],
#        [ 94,  75],
#        [100,  82]])
