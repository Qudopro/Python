# %%
dictionary = {}

# %%
country_codes = {'Finland':'fi', 'South Africa':'za', 'Nepal':'np'}
print(country_codes)
# Out:
# {'Finland': 'fi', 'South Africa': 'za', 'Nepal': 'np'}

# %%
len(country_codes)
# Out:
# 3

# %%
if country_codes:
    print('country_codes is not empty')
else:
    print('country_codes is empty')
# Out:
# country_codes is empty

# %%
country_codes.clear()

# %%
days_per_month = {'January': 31, 'February': 28, 'March': 30, 'April': 31}
print(days_per_month)
# Out:
# {'January': 31, 'February': 28, 'March': 30, 'April': 31}

# %%
for month, days in days_per_month.items():
    print(f'{month} has {days} days')
# Out:
# January has 31 days
# February has 28 days
# March has 30 days
# April has 31 days

# %%
roman_numerals = {'I':1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IV':9, 'X':100}

# %%
roman_numerals
# Out:
# {'I': 1,
#  'II': 2,
#  'III': 3,
#  'IV': 9,
#  'V': 5,
#  'VI': 6,
#  'VII': 7,
#  'VIII': 8,
#  'X': 100}

# %%
roman_numerals['X']
# Out:
# 100

# %%
roman_numerals['X'] = 10

# %%
print(roman_numerals)
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'IV': 9, 'V': 5, 'VI': 6, 'VII': 7, 'VIII': 8, 'X': 10}

# %%
roman_numerals['L'] = 50
print(roman_numerals)
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'IV': 9, 'V': 5, 'VI': 6, 'VII': 7, 'VIII': 8, 'X': 10, 'L': 50}

# %%
del roman_numerals['L']

# %%
roman_numerals.pop('X')
# Out:
# 10

# %%
roman_numerals['L']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 roman_numerals['L']
#
# KeyError: 'L'

# %%
roman_numerals.get('III')
# Out:
# 3

# %%
roman_numerals.get('L', 'L not found in dictionary')
# Out:
# 'L not found in dictionary'

# %%
'III' in roman_numerals
# Out:
# True

# %%
'L' not in roman_numerals
# Out:
# True

# %%
for month in days_per_month.keys():
    print(month, end=' ')
# Out:
# January February March April

# %%
for days in days_per_month.values():
    print(days, end=' ')
# Out:
# 31 28 30 31

# %%
months_view = days_per_month.keys()

for month in months_view:
    print(month, end=' ')
# Out:
# January February March April

# %%
days_per_month['March'] = 31

# %%
days_per_month
# Out:
# {'January': 31, 'February': 28, 'March': 31, 'April': 31}

# %%
for key in months_view:
    print(key, end=' ')
# Out:
# January February March April

# %%
list(days_per_month.values())
# Out:
# [31, 28, 30, 31]

# %%
list(days_per_month.keys())
# Out:
# ['January', 'February', 'March', 'April']

# %%
list(days_per_month.items())
# Out:
# [('January', 31), ('February', 28), ('March', 30), ('April', 31)]

# %%
for month_name in sorted(days_per_month.keys()):
    print(month_name, end=' ')
# Out:
# April February January March

# %%
country_capitals1 = {'Belgium': 'Brussels', 'Haiti': 'Port-au-Prince'}

# %%
country_capitals2 = {'Nepal': 'Kathmandu', 'Uruguay': 'Montevideo'}

# %%
country_capitals1 == country_capitals2
# Out:
# False

# %%
country_capitals1 != country_capitals2
# Out:
# True

# %%
from collections import Counter
text = ('this is sample text with several words'
        ' this is more sample text with some different words')

# %%
counter =Counter(text.split())

# %%
for word, count in sorted(counter.items()):
    print(f'{word:<12}: {count}')
# Out:
# different   : 1
# is          : 2
# more        : 1
# sample      : 2
# several     : 1
# some        : 1
# text        : 2
# this        : 2
# with        : 2
# words       : 2

# %%
country_codes2 ={}

# %%
country_codes2.update({'South Africa': 'za'})

# %%
country_codes2.update(Australia='ar')

# %%
print(country_codes2)
# Out:
# {'South Africa': 'za', 'Australia': 'ar'}

# %%
country_codes2.update(Australia='au')

# %%
print(country_codes2)
# Out:
# {'South Africa': 'za', 'Australia': 'au'}

# %%
months = {'January': 1, 'February': 2, 'March': 3, 'April': 4}
print(months)
# Out:
# {'January': 1, 'February': 2, 'March': 3, 'April': 4}

# %%
months2 = {number: name for name, number in months.items()}
print(months2)
# Out:
# {1: 'January', 2: 'February', 3: 'March', 4: 'April'}

# %%
grades = {'Sue':[98,87,94], 'Bob':[84,95,91]}
grades2 = {k:sum(v)/len(v) for k, v in grades.items()}

# %%
grades2
# Out:
# {'Sue': 93.0, 'Bob': 90.0}
