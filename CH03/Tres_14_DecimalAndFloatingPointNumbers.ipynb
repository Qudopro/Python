# %%
amount = 112.31
print(amount)
# Out:
# 112.31

# %%
print(f'{amount:.20f}')
# Out:
# 112.31000000000000227374

# %%
import decimal
decimal.Decimal

# %%
from decimal import Decimal             #Import only the type Decimal from the decimal module

# %%
principal = Decimal("1000.00")
principal
# Out:
# Decimal('1000.00')

# %%
rate = Decimal("0.05")
rate
# Out:
# Decimal('0.05')

# %%
x = Decimal("10.5")
y = Decimal("2")

x+y
# Out:
# Decimal('12.5')

# %%
x//y
# Out:
# Decimal('5')

# %%
x+=y
x
# Out:
# Decimal('12.5')

# %%
for year in range(1, 11):
    amount = principal*(1+rate)**year
    print(f"{year:>2}{amount:>10.2f}")
# Out:
#  1   1050.00
#  2   1102.50
#  3   1157.62
#  4   1215.51
#  5   1276.28
#  6   1340.10
#  7   1407.10
#  8   1477.46
#  9   1551.33
# 10   1628.89
