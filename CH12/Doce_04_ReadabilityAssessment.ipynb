# %%
from pathlib import Path

# %%
text = Path('pg1513.txt').read_text(encoding="UTF-8", errors="ignore")

# %%
#Calculate statistics and readability scores

# %%
from textatistic import Textatistic

# %%
readability = Textatistic(text)             #Text you want to assess

# %%
readability.dict()
# Out:
# {'char_count': 131171,
#  'word_count': 29180,
#  'sent_count': 3398,
#  'sybl_count': 35228,
#  'notdalechall_count': 6845,
#  'polysyblword_count': 1032,
#  'flesch_score': 95.98414441466798,
#  'fleschkincaid_score': 2.004817650668196,
#  'gunningfog_score': 4.8496293227359075,
#  'smog_score': 6.277378163900472,
#  'dalechall_score': 7.766429430124804}

# %%
#Where:
#char_count = Number of characters in text
#word_count = Number of words
#sent_count = The number of sentences in the text
#sybl_count = Number of syllables in the text
#notdalechall_count = A count of the words that are not on the Dale-Chall list
#polysyblword_count = The number of words with three or more syllables
#flesch_score = The Flesch Reading Ease score
#fleschkindcaid_score = The Flesch-Kincaid score, which corresponds to a specific grade level
#gunningfog_score = The Gunning Fog index value, which corresponds to a specific grade level
#smog_score = The Simple Measure of Gobbledygook (SMOG) which corresponds to the years of education required to understan text
#dalechall_score = The Dale-Chall score.
