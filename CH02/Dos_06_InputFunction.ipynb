# %%
name = input("What is your name? ")

# %%
print(name)
# Out:
# Diego

# %%
name
# Out:
# 'Diego'

# %%
value = input("Enter an integer: ")

# %%
another_value = input("Enter an integer: ")

# %%
value
# Out:
# '43'

# %%
another_value
# Out:
# '75'

# %%
value + another_value       #String concatenation
# Out:
# '4375'

# %%
value = int(value)

# %%
another_value = int(another_value)

# %%
value
# Out:
# 43

# %%
another_value
# Out:
# 75

# %%
another_value = int(input("Enter an integer: "))   #Combined the code

# %%
print("Sum is: ", value + another_value)
# Out:
# Sum is:  118

# %%
int(10.5)
# Out:
# 10

# %%
float('92')
# Out:
# 92.0

# %%
float_value = float(input("Enter a float value: "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 float_value = float(input("Enter a float value: "))
#
# ValueError: could not convert string to float: 'kd'
