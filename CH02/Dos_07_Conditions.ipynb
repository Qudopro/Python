# %%
7 > 4                   #7 Greater than 4
# Out:
# True

# %%
7 < 4                   #7 Less than 4
# Out:
# False

# %%
7 >= 4
# Out:
# True

# %%
4 <= 7
# Out:
# True

# %%
7 == 7
# Out:
# True

# %%
7 != 4
# Out:
# True

# %%
7 ! = 4
# Out:
#   Cell In[2], line 1
#     7 ! = 4
#       ^
# SyntaxError: invalid syntax

# %%
x = 3
1 <= x <= 5
# Out:
# True
