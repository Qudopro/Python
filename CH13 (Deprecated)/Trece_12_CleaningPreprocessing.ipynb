# %%
import preprocessor as p

# %%
p.set_options(p.OPT.URL, p.OPT.RESERVED)            #Remove URLs and Twitter reserved words
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p.set_options(p.OPT.URL, p.OPT.RESERVED)            #Remove URLs and Twitter reserved words
#
# AttributeError: module 'preprocessor' has no attribute 'set_options'

# %%
tweet_text = 'RT A sample retweet with a URL https://nasa.gov'

# %%
p.clean(tweet_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 p.clean(tweet_text)
#
# AttributeError: module 'preprocessor' has no attribute 'clean'
