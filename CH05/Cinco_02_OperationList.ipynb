# %%
c = [-45,6,0,72,1543]

# %%
c
# Out:
# [-45, 6, 0, 72, 1543]

# %%
c = ["Diego", "Cabrera", 22, 4949]

# %%
c
# Out:
# ['Diego', 'Cabrera', 22, 4949]

# %%
c[0]
# Out:
# 'Diego'

# %%
c[3]
# Out:
# 4949

# %%
len(c)              #Longitud de una lista
# Out:
# 4

# %%
c[-1]
# Out:
# 4949

# %%
c[-4]
# Out:
# 'Diego'

# %%
a = 2
b = 1
c[a+b]              #c[3]
# Out:
# 4949

# %%
c['hola']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 c['hola']
#
# TypeError: list indices must be integers or slices, not str

# %%
c
# Out:
# ['Diego', 'Cabrera', 22, 4949]

# %%
c[2] = 21

# %%
c
# Out:
# ['Diego', 'Cabrera', 21, 4949]

# %%
s = "hello"
s[0]
# Out:
# 'h'

# %%
s[0] = "i"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s[0] = "i"
#
# TypeError: 'str' object does not support item assignment

# %%
c[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 c[100]
#
# IndexError: list index out of range

# %%
sum = c[2] + c[3]
sum
# Out:
# 4970

# %%
a_list = []                 #Empty list
for number in range(1,6):
    a_list += [number]          #An iterable as right operand. It prevents a TypeError. [number] is a one element list

a_list
# Out:
# [1, 2, 3, 4, 5]

# %%
letters = []
letters += "Python"
letters
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
tuple_list = []
tuple_list += (12,23,43)
tuple_list
# Out:
# [12, 23, 43]

# %%
list1 = [10,20,30]
list2 = [40,50, 60]
concatenated_list = list1 + list2           #A TypeError occurs if the operands are different sequence types
concatenated_list
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
for i in range(len(concatenated_list)):
    print(f'{i}: {concatenated_list[i]}')
# Out:
# 0: 10
# 1: 20
# 2: 30
# 3: 40
# 4: 50
# 5: 60

# %%
a = [1,2,3,4,5]
b = [1,2,3,4,5]
c = [1,2,3,4,5,6]

# %%
a == b
# Out:
# True

# %%
a == c
# Out:
# False

# %%
a < c                   #True: a has fewer elements than c
# Out:
# True

# %%
c >= b                  #True: c has more elements, and elements 0-2 are equal
# Out:
# True
