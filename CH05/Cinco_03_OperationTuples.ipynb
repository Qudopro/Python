# %%
student_tuple = ()

# %%
student_tuple
# Out:
# ()

# %%
len(student_tuple)
# Out:
# 0

# %%
student_tuple = 'John', 'Green', 2.2

# %%
student_tuple
# Out:
# ('John', 'Green', 2.2)

# %%
len(student_tuple)
# Out:
# 3

# %%
another_student_tuple = ('John', 'Green', 2.2)

# %%
another_student_tuple
# Out:
# ('John', 'Green', 2.2)

# %%
a_singleton_student_tuple = ('John',)

# %%
a_singleton_student_tuple
# Out:
# ('John',)

# %%
time_tuple = (9,16,1)           #Hora, Minuto, Segundo
time_tuple
# Out:
# (9, 16, 1)

# %%
time_tuple[0] *3600 + time_tuple[1] *60 + time_tuple[2]  #Cuanto tiempo ha pasado desde la media noche
# Out:
# 33361

# %%
tuple1 = (10, 20, 30)
tuple2 = tuple1

# %%
tuple1 += (40, 50)              #It creates a new tuple, then assigns a reference to it to the variable tuple1
tuple1
# Out:
# (10, 20, 30, 40, 50)

# %%
tuple2                          #Tuple2 still refers to the original tuple
# Out:
# (10, 20, 30)

# %%
numbers = [1,2,3,4,5]
numbers += (6,7)               #Append a tuple to a list
numbers
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
student_tuple = ('Amanda', 'Blue', [98,75,97])

# %%
student_tuple[2][1] = 85                #[tuple_element][list_element]

# %%
student_tuple
# Out:
# ('Amanda', 'Blue', [98, 85, 97])
