# %%
a = [[77,68,86,73], [97,86,89,81],[70,90,86,81]]

# %%
for row in a:
    for col in row:
        print(col, end=' ')
    print()
# Out:
# 77 68 86 73
# 97 86 89 81
# 70 90 86 81

# %%
for i, row in enumerate(a):
    for j, col in enumerate(row):
        print(f'a[{i}][{j}]={col} ', end=' ')
    print()
# Out:
# a[0][0]=77  a[0][1]=68  a[0][2]=86  a[0][3]=73
# a[1][0]=97  a[1][1]=86  a[1][2]=89  a[1][3]=81
# a[2][0]=70  a[2][1]=90  a[2][2]=86  a[2][3]=81
