# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import random

# %%
import seaborn as sns

# %%
roll = [random.randrange(1,7) for i in range(6000000)]

# %%
values, frequencies = np.unique(roll, return_counts=True)

# %%
title = f'Rolling a Six-Sided Die {len(roll):,} times'

# %%
sns.set_style('whitegrid')

# %%
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set_title(title)
axes.set(xlabel='Die Value', ylabel='Frequency')
axes.set_ylim(top=max(frequencies)*1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x()+bar.get_width()/2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency/len(roll):.3%}'
    axes.text(text_x, text_y, text, ha='center', va='bottom')
# Out:
# /var/folders/63/gf625r8n0617vd2sp9ng3csh0000gn/T/ipykernel_3807/400624011.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette='bright')

# %%
plt.show()
