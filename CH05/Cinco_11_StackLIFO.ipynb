# %%
stack = []
stack.append('red')
stack.append('blue')
stack.append('green')
stack
# Out:
# ['red', 'blue', 'green']

# %%
stack.pop()
# Out:
# 'green'

# %%
stack.pop()
# Out:
# 'blue'

# %%
stack.pop()
# Out:
# 'red'

# %%
stack.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 stack.pop()
#
# IndexError: pop from empty list
