# %%
from dataclasses import dataclass

from CH10.Diez_06_CardShufflingAndDealingSimulation import deck_of_cards

# %%
@dataclass
class Demo:
    x                   #attempting to create a data attribute x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 @dataclass
# ----> 2 class Demo:
#       3     x                   #attempting to create a data attribute x
#
# Cell In[2], line 3, in Demo()
#       1 @dataclass
#       2 class Demo:
# ----> 3     x
#
# NameError: name 'x' is not defined

# %%
from carddataclass import Card

# %%
c1 = Card(Card.FACES[0], Card.SUITS[3])

# %%
c1              #Call to __repr__ method
# Out:
# Card(face='Ace', suit='Spades')

# %%
print(c1)       #Call to __str__method
# Out:
# Ace of Spades

# %%
c1.face
# Out:
# 'Ace'

# %%
c1.suit
# Out:
# 'Spades'

# %%
c1.image_name
# Out:
# 'Ace_of_Spades.png'

# %%
c2 = Card(Card.FACES[0], Card.SUITS[3])

# %%
c2
# Out:
# Card(face='Ace', suit='Spades')

# %%
c3 = Card(Card.FACES[0], Card.SUITS[0])

# %%
c3
# Out:
# Card(face='Ace', suit='Hearts')

# %%
c1 == c2
# Out:
# True

# %%
c1 == c3
# Out:
# False

# %%
c1 != c3
# Out:
# True

# %%
from deck2 import DeckOfCards

# %%
deck_of_cards = DeckOfCards()

# %%
print(deck_of_cards)
# Out:
# Ace of Hearts      2 of Hearts        3 of Hearts        4 of Hearts
# 5 of Hearts        6 of Hearts        7 of Hearts        8 of Hearts
# 9 of Hearts        10 of Hearts       Jack of Hearts     Queen of Hearts
# King of Hearts     Ace of Diamonds    2 of Diamonds      3 of Diamonds
# 4 of Diamonds      5 of Diamonds      6 of Diamonds      7 of Diamonds
# 8 of Diamonds      9 of Diamonds      10 of Diamonds     Jack of Diamonds
# Queen of Diamonds  King of Diamonds   Ace of Clubs       2 of Clubs
# 3 of Clubs         4 of Clubs         5 of Clubs         6 of Clubs
# 7 of Clubs         8 of Clubs         9 of Clubs         10 of Clubs
# Jack of Clubs      Queen of Clubs     King of Clubs      Ace of Spades
# 2 of Spades        3 of Spades        4 of Spades        5 of Spades
# 6 of Spades        7 of Spades        8 of Spades        9 of Spades
# 10 of Spades       Jack of Spades     Queen of Spades    King of Spades
