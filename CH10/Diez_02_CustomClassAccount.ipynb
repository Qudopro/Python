# %%
from account import Account
from decimal import Decimal

# %%
value = Decimal('12.34')
print(value)
# Out:
# 12.34

# %%
account1 = Account('John Green', Decimal('50.00'))          #Create a new object

# %%
account1.name
# Out:
# 'John Green'

# %%
account1.balance
# Out:
# Decimal('50.00')

# %%
account1.deposit(Decimal('25.53'))

# %%
account1.balance
# Out:
# Decimal('75.53')

# %%
account1.deposit(Decimal('-123.45'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 account1.deposit(Decimal('-123.45'))
#
# File ~\Sistemas\Estudio\Python\PHTP\Python\CH10\account.py:20, in Account.deposit(self, amount)
#      18 """Deposit money to the account."""
#      19 if(amount < Decimal('0.00')):
# ---> 20     raise ValueError('Insufficient balance. Balance cannot be negative.')
#      22 self.balance += amount
#
# ValueError: Insufficient balance. Balance cannot be negative.
