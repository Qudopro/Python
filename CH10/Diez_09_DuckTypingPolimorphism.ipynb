# %%
from decimal import Decimal

# %%
from commissionemployee import CommissionEmployee

# %%
from salariedcommissionemployee import SalariedCommissionEmployee

# %%
from wellpaidduck import WellPaidDuck

# %%
c = CommissionEmployee('Sue', 'Jones', '333-33-3333', Decimal('10000.00'), Decimal('0.06'))

# %%
s = SalariedCommissionEmployee('Bob', 'Lewis', '444-44-4444', Decimal('0.00'), Decimal('0.01'), Decimal('300.00'))

# %%
d = WellPaidDuck()

# %%
employees = [c, s, d]

# %%
for employee in employees:
    print(employee)
    print(f'{employee.earnings():,.2f}\n')
# Out:
# CommissionEmployee: Sue Jones
# social security number: 333-33-3333
# gross sales: 10000.00
# commission rate: 0.06
#
# 600.00
#
# SalariedCommissionEmployee: Bob Lewis
# social security number: 444-44-4444
# gross sales: 0.00
# commission rate: 0.01
# base_salary: 300.00
# 300.00
#
# I am well-paid duck
# 1,000,000.00
