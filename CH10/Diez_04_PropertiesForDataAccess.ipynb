# %%
from timewithproperties import Time

# %%
wake_up = Time(hour=6, minute=30)

# %%
wake_up             #Call the object's __repr__ special method. It produces a string representation of the object
# Out:
# Time(hour=6, minute=30, second=0)

# %%
print(wake_up)      #Call the __str__ special method. It's called when an object is converted to a string
# Out:
# 6:30:00 AM

# %%
wake_up.hour
# Out:
# 6

# %%
wake_up.set_time(hour=7, minute=45)
print(wake_up)
# Out:
# 7:45:00 AM

# %%
wake_up.hour = 6
wake_up
# Out:
# Time(hour=6, minute=45, second=0)

# %%
wake_up.hour = 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 wake_up.hour = 100
#
# File ~\Sistemas\Estudio\Python\PHTP\Python\CH10\timewithproperties.py:23, in Time.hour(self, hour)
#      21 """Set hour."""
#      22 if not(0 <= hour <= 23):
# ---> 23     raise ValueError(f'hour {hour} must be between 0 and 23')
#      24 self._hour = hour
#
# ValueError: hour 100 must be between 0 and 23

# %%
wake_up._hour
# Out:
# 6

# %%
wake_up._hour = 100

# %%
wake_up
# Out:
# Time(hour=100, minute=45, second=0)
