# %%
accounts_dict = {"accounts": [
    {"account": 100, "name": "Jones", "balance": 24.98},
    {"account": 200, "name": "Diego", "balance": 30.00}]}

# %%
import json

# %%
with(open("accounts.json", mode='w')) as accounts:
    json.dump(accounts_dict, accounts)

# %%
with open("accounts.json", mode='r') as accounts:
    accounts_json = json.load(accounts)
    print(accounts_json["accounts"])
# Out:
# [{'account': 100, 'name': 'Jones', 'balance': 24.98}, {'account': 200, 'name': 'Diego', 'balance': 30.0}]

# %%
with open("accounts.json", mode='r') as accounts:
    print(json.dumps(json.load(accounts), indent=4))
# Out:
# {
#     "accounts": [
#         {
#             "account": 100,
#             "name": "Jones",
#             "balance": 24.98
#         },
#         {
#             "account": 200,
#             "name": "Diego",
#             "balance": 30.0
#         }
#     ]
# }
