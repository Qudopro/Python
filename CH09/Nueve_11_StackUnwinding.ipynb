# %%
def function1():
    function2()

def function2():
    raise Exception("An exception occurred")

print(function1())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 def function2():
#       5     raise Exception("An exception occurred")
# ----> 7 print(function1())
#
# Cell In[4], line 2, in function1()
#       1 def function1():
# ----> 2     function2()
#
# Cell In[4], line 5, in function2()
#       4 def function2():
# ----> 5     raise Exception("An exception occurred")
#
# Exception: An exception occurred
